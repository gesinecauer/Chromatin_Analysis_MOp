# %% [markdown]
# # Load sc distances

# %%
# %load_ext autoreload
# %autoreload 1

# %aimport topsy.analysis.compare_distances

from topsy.analysis.compare_distances import get_sc_disterror_all
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob
import os
import re
import numpy as np
import pandas as pd
from topsy.analysis.compare_distances import load_sc_dis_per_locus as load_sc_dis_per_locus_tmp
from topsy.analysis.compare_distances import load_sc_struct_features as load_sc_struct_features_tmp
# from topsy.analysis.compare_distances import scale_sc_distances as scale_sc_distances_tmp


# counts_subdir = 'astro.nreads1e8.sc_alpha-3'
# counts_subdir = 'astro.nreads1e9.logistic_k-14.71_m0.4515'

# IMPUTED, NOT NORMALIZED
# counts_subdir = 'astro.nreads1e9.logistic_k-5.16_m2.69_v1.23e-05'  # obj=-0.88644655 → PEARSON.infer_nu.kmax-4_buffer1e-5_d0min50p, seed=0  (FACTR) - IMPUTED, NOT normalized
counts_subdir = 'astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05'  # obj=0.18979348 → RMSE.infer_nu.kmax-4_buffer1e-5_d0min50p, seed=0  (FACTR) - IMPUTED, NOT normalized


# counts_subdir = 'astro.nreads1e9.logistic_k-12.34_m1.36_v5.666e-06'  # constraint v2

sc_dis_file = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/{counts_subdir}/struct_true.distances.per_locus.tsv'
sc_features_file = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/{counts_subdir}/struct_true.features.tsv'

struct_infer_file = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/{counts_subdir}/infer_ua_filter0perc.singleres/struct_inferred.000.coords'
# dataset_info_file = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/data/liu2025/unambig/{counts_subdir}/dataset_info.txt'
dataset_dir = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/{counts_subdir}/'

struct_infer_glob = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/{counts_subdir}/infer_*/struct_inferred.*.coords'
# struct_infer_files = sorted(glob.glob(struct_infer_glob))

# sc_dis = load_sc_dis_per_locus_tmp(sc_dis_file, scale=False, verbose=True).drop('same_molecule', axis=1)
# sc_dis = scale_sc_distances_tmp(sc_dis, dataset_dir=dataset_dir, copy=False, verbose=True)

# %%
sc_features = load_sc_struct_features_tmp(sc_features_file, verbose=True)

sc_dis = load_sc_dis_per_locus_tmp(sc_dis_file, verbose=True).drop('same_molecule', axis=1)
# sc_dis = scale_sc_distances_tmp(sc_dis, dataset_dir=dataset_dir, copy=False, verbose=True)
# Out:
# Loading sc structural features... DONE
# Loading sc distances... DONE

# %% [markdown]
# # Test

# %% [markdown]
# ## snm3c

# %%
# %reload_ext autoreload
from topsy.analysis.compare_distances import get_sc_disterror_all

snm3c_counts_subdir = "snm3c_q.norm/chr1";
# infer_dir = "infer_ambig_filter0perc.alpha_infer-intramol.beta_infer.singleres";
snm3c_struct_infer_glob = f'/net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/snm3c/{snm3c_counts_subdir}/infer_*/struct_inferred.*.coords'
struct_infer_files = sorted(glob.glob(snm3c_struct_infer_glob))
print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')

get_sc_disterror_all(
    struct_infer_files[0], sc_dis=sc_dis
    , sc_features=sc_features, rescale=True, hmlg_order_known=False,
    redo=True, verbose=True)
# Out:
# infer_ambig_filter0perc.alpha_infer-intramol.beta_infer.singleres
#
# /net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/snm3c/snm3c_q.norm/chr1/infer_ambig_filter0perc.alpha_infer-intramol.beta_infer.singleres/struct_inferred.000.coords
#
#
# liu2025/snm3c/snm3c_q.norm/chr1/infer_ambig_filter0perc.alpha_infer-intramol.beta_infer.singleres/disterror_per_bin.true_vs_infer000.rescaled
# Comparing intra-molecular distance bins and matching up homologs
# Rescaling inferred struct using all single-cell distances between neighboring beads...
# 	....Scale factor=0.198
# 	dis_infer        0.7331
# 	dis_infer.swap   0.7277
# 	dis_mean          1.065
# 	dis_med           1.016
# Homolog labels were not swapped for any chrom
# Comparing all distance bins
# Rescaling inferred struct using all single-cell distances between neighboring beads...
# 	....Scale factor=1.01
# 	dis_infer   0.7372
# 	dis_mean     1.065
# 	dis_med      1.016
# /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:265: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.7178141070108841 0.2678607181137553 1.4441888127378424 ...
#  16.554900465305156 16.47517298279927 14.302454203482869]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   res_df.loc[mask, 'disterror.vs_mean'] = (
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 11
#       8 print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
#       9 print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')
# ---> 11 get_sc_disterror_all(
#      12     struct_infer_files[0], sc_dis=sc_dis
#      13     , sc_features=sc_features, rescale=True, hmlg_order_known=False,
#      14     redo=True, verbose=True)
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:590, in get_sc_disterror_all(struct_infer_files, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     588 disterror_res_mean = []
#     589 for struct_infer_file in struct_infer_files:
# --> 590     matrix_df, features_df, error, inference_type = compare_infer_vs_true(
#     591         struct_infer_file, sc_dis=sc_dis, sc_features=sc_features,
#     592         rescale=rescale, hmlg_order_known=hmlg_order_known, redo=redo,
#     593         verbose=verbose)
#     594     disterror_res = get_disterror_from_sq_dis(matrix_df, verbose=False)
#     595     disterror_res['inference'] = inference_type
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:406, in compare_infer_vs_true(struct_infer_file, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     401 else:
#     402     features_df = pd.DataFrame(
#     403         index=np.array(
#     404             [[f"{x}_mse", f"{x}_err"] for x in sc_features.index]).ravel(),
#     405         columns=[x.replace('sc_', 'vs_') for x in sc_features.columns])
# --> 406     inferred_features = get_other_struct_features(
#     407         matrix_df, dis_df='dis_infer')
#     408     for feature_name, val_infer in inferred_features.items():
#     409         vals_sc = sc_features.loc[feature_name]
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:325, in get_other_struct_features(matrix_df, dis_df, ploidy)
#     320     idx_hmlg1 = matrix_df[matrix_df['i.hmlg'] == 1].index
#     321     idx_hmlg2 = list(map(tuple, (
#     322         np.array(idx_hmlg1.values.tolist()) + n).tolist()))
#     324     sq_diff = np.square(
# --> 325         dis_df.loc[idx_hmlg1].values - dis_df.loc[idx_hmlg2].values)
#     326     results['btwn-hmlgs_disterror'] = np.sqrt(np.nanmean(
#     327         sq_diff[:, ~np.all(np.isnan(sq_diff), axis=0)], axis=0))
#     329 if len(dis_df.columns) == 1:
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/local/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[(77, 79), (77, 101), (77, 110), (77, 115), (77, 118), (77, 120), (77, 136), (77, 138), (77, 146), (78, 79), (78, 101), (78, 110), (78, 115), (78, 118), (78, 120), (78, 136), (78, 138), (78, 146), (79, 80), (79, 81), (79, 82), (79, 83), (79, 84), (79, 85), (79, 86), (79, 87), (79, 88), (79, 89), (79, 90), (79, 91), (79, 92), (79, 93), (79, 94), (79, 95), (79, 96), (79, 97), (79, 98), (79, 99), (79, 100), (79, 101), (79, 102), (79, 103), (79, 104), (79, 105), (79, 106), (79, 108), (79, 109), (79, 110), (79, 111), (79, 112), (79, 113), (79, 114), (79, 115), (79, 116), (79, 117), (79, 118), (79, 119), (79, 120), (79, 121), (79, 122), (79, 123), (79, 124), (79, 125), (79, 126), (79, 127), (79, 128), (79, 129), (79, 130), (79, 131), (79, 132), (79, 133), (79, 134), (79, 135), (79, 136), (79, 137), (79, 138), (79, 139), (79, 140), (79, 141), (79, 142), (79, 143), (79, 144), (79, 145), (79, 146), (79, 147), (79, 148), (79, 149), (79, 150), (79, 151), (79, 152), (79, 153), (80, 101), (80, 110), (80, 115), (80, 118), (80, 120), (80, 136), (80, 138), (80, 146), (81, 101), (81, 110), (81, 115), (81, 118), (81, 120), (81, 136), (81, 138), (81, 146), (82, 101), (82, 110), (82, 115), (82, 118), (82, 120), (82, 136), (82, 138), (82, 146), (83, 101), (83, 110), (83, 115), (83, 118), (83, 120), (83, 136), (83, 138), (83, 146), (84, 101), (84, 110), (84, 115), (84, 118), (84, 120), (84, 136), (84, 138), (84, 146), (85, 101), (85, 110), (85, 115), (85, 118), (85, 120), (85, 136), (85, 138), (85, 146), (86, 101), (86, 110), (86, 115), (86, 118), (86, 120), (86, 136), (86, 138), (86, 146), (87, 101), (87, 110), (87, 115), (87, 118), (87, 120), (87, 136), (87, 138), (87, 146), (88, 101), (88, 110), (88, 115), (88, 118), (88, 120), (88, 136), (88, 138), (88, 146), (89, 101), (89, 110), (89, 115), (89, 118), (89, 120), (89, 136), (89, 138), (89, 146), (90, 101), (90, 110), (90, 115), (90, 118), (90, 120), (90, 136), (90, 138), (90, 146), (91, 101), (91, 110), (91, 115), (91, 118), (91, 120), (91, 136), (91, 138), (91, 146), (92, 101), (92, 110), (92, 115), (92, 118), (92, 120), (92, 136), (92, 138), (92, 146), (93, 101), (93, 110), (93, 115), (93, 118), (93, 120), (93, 136), (93, 138), (93, 146), (94, 101), (94, 110), (94, 115), (94, 118), (94, 120), (94, 136), (94, 138), (94, 146), (95, 101), (95, 110), (95, 115), (95, 118), (95, 120), (95, 136), (95, 138), (95, 146), (96, 101), (96, 110), (96, 115), (96, 118), (96, 120), (96, 136), (96, 138), (96, 146), (97, 101), (97, 110), (97, 115), (97, 118), (97, 120), (97, 136), (97, 138), (97, 146), (98, 101), (98, 110), (98, 115), (98, 118), (98, 120), (98, 136), (98, 138), (98, 146), (99, 101), (99, 110), (99, 115), (99, 118), (99, 120), (99, 136), (99, 138), (99, 146), (100, 101), (100, 110), (100, 115), (100, 118), (100, 120), (100, 136), (100, 138), (100, 146), (101, 102), (101, 103), (101, 104), (101, 105), (101, 106), (101, 108), (101, 109), (101, 110), (101, 111), (101, 112), (101, 113), (101, 114), (101, 115), (101, 116), (101, 117), (101, 118), (101, 119), (101, 120), (101, 121), (101, 122), (101, 123), (101, 124), (101, 125), (101, 126), (101, 127), (101, 128), (101, 129), (101, 130), (101, 131), (101, 132), (101, 133), (101, 134), (101, 135), (101, 136), (101, 137), (101, 138), (101, 139), (101, 140), (101, 141), (101, 142), (101, 143), (101, 144), (101, 145), (101, 146), (101, 147), (101, 148), (101, 149), (101, 150), (101, 151), (101, 152), (101, 153), (102, 110), (102, 115), (102, 118), (102, 120), (102, 136), (102, 138), (102, 146), (103, 110), (103, 115), (103, 118), (103, 120), (103, 136), (103, 138), (103, 146), (104, 110), (104, 115), (104, 118), (104, 120), (104, 136), (104, 138), (104, 146), (105, 110), (105, 115), (105, 118), (105, 120), (105, 136), (105, 138), (105, 146), (106, 110), (106, 115), (106, 118), (106, 120), (106, 136), (106, 138), (106, 146), (108, 110), (108, 115), (108, 118), (108, 120), (108, 136), (108, 138), (108, 146), (109, 110), (109, 115), (109, 118), ( ...

# %% [markdown]
# ## 'True' alpha

# %%
# %reload_ext autoreload
from topsy.analysis.compare_distances import get_sc_disterror_all

struct_infer_files = sorted(glob.glob(struct_infer_glob))
struct_infer_files = [x for x in struct_infer_files if 'norm' not in x and 'filter0perc' in x]
struct_infer_files = [x for x in struct_infer_files if 'alpha_infer-intrachr' not in x and 'multires' not in x]
struct_infer_files = [x for x in struct_infer_files if 'alpha_infer' not in x]
# struct_infer_files = [x for x in struct_infer_files if '.intramol' in x]
print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')

get_sc_disterror_all(
    struct_infer_files[0], sc_dis=sc_dis
    , sc_features=sc_features, rescale=True, hmlg_order_known=None,
    redo=False, verbose=True)
# Out:
# infer_ua_filter0perc.singleres
#
# infer_ua_filter0perc.singleres/struct_inferred.000.coords
#
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer000.rescaled
# Assuming homolog ordering of inferred structure has been pre-established
# count    250.000000
# mean       4.365384
# std        2.175656
# min        0.169671
# 1%         0.218183
# 5%         0.304285
# 10%        0.407544
# 25%        3.268323
# 50%        4.916885
# 75%        6.041848
# 90%        6.720663
# 95%        7.103858
# 99%        7.701722
# max        8.020699
# Name: dis_infer, dtype: float64
# Comparing all distance bins
# count   1.64e+03
# mean        1.29
# std         1.17
# min        0.392
# 1%         0.733
# 5%         0.773
# 10%        0.795
# 25%        0.836
# 50%        0.906
# 75%         1.08
# 90%         1.86
# 95%         3.98
# 99%         6.79
# max          8.3
#
#
# Involving both neighbors of locus (19):
#               i.idx_chrom  j.idx_chrom i.chrom  i.hmlg  dis_infer
# idx
# (96, 97)               19           20    chr2       1   6.352850
# (97, 98)               20           21    chr2       1   7.232702
# (539, 540)             39           40    chr8       1   6.376822
# (540, 541)             40           41    chr8       1   6.553862
# (1059, 1060)           19           20    chr2       2   6.517452
# (1060, 1061)           20           21    chr2       2   7.246825
# (1312, 1313)           15           16    chr6       2   7.647782
# (1313, 1314)           16           17    chr6       2   7.258163
# (1502, 1503)           39           40    chr8       2   7.112071
# (1503, 1504)           40           41    chr8       2   7.330733
# (1626, 1627)           15           16   chr12       2   7.830733
# (1627, 1628)           16           17   chr12       2   7.210583
# (1663, 1664)            5            6   chr13       2   8.301956
# (1664, 1665)            6            7   chr13       2   7.658285
# (1666, 1667)            8            9   chr13       2   7.575475
# (1667, 1668)            9           10   chr13       2   6.746652
# (1668, 1669)           10           11   chr13       2   6.796618
# (1687, 1688)           29           30   chr13       2   8.031391
# (1688, 1689)           30           31   chr13       2   8.137425
#
# Only involve ONE neibhor of locus (14):
#               i.idx_chrom  j.idx_chrom i.chrom  i.hmlg  dis_infer
# idx
# (92, 93)               15           16    chr2       1   6.640376
# (129, 130)             52           53    chr2       1   7.080707
# (382, 383)             48           49    chr6       1   6.344317
# (805, 806)             17           18   chr15       1   6.346708
# (1092, 1093)           52           53    chr2       2   6.412089
# (1307, 1308)           10           11    chr6       2   6.257685
# (1310, 1311)           13           14    chr6       2   6.748595
# (1323, 1324)           26           27    chr6       2   6.772552
# (1335, 1336)           38           39    chr6       2   6.669541
# (1351, 1352)           54           55    chr6       2   6.757938
# (1679, 1680)           21           22   chr13       2   6.376732
# (1685, 1686)           27           28   chr13       2   6.852699
# (1834, 1835)            4            5   chr17       2   7.489676
# (1842, 1843)           12           13   chr17       2   6.734859
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 12
#       9 print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
#      10 print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')
# ---> 12 get_sc_disterror_all(
#      13     struct_infer_files[0], sc_dis=sc_dis
#      14     , sc_features=sc_features, rescale=True, hmlg_order_known=None,
#      15     redo=False, verbose=True)
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:549, in get_sc_disterror_all(struct_infer_files, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     547 disterror_res_mean = []
#     548 for struct_infer_file in struct_infer_files:
# --> 549     matrix_df, features_df, error, inference_type = compare_infer_vs_true(
#     550         struct_infer_file, sc_dis=sc_dis, sc_features=sc_features,
#     551         rescale=rescale, hmlg_order_known=hmlg_order_known, redo=redo,
#     552         verbose=verbose)
#     553     disterror_res = get_disterror_from_sq_dis(matrix_df, verbose=False)
#     554     disterror_res['inference'] = inference_type
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:352, in compare_infer_vs_true(struct_infer_file, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     348     matrix_df = pd.read_csv(
#     349         outfile_perbin, sep='\t', index_col=0,
#     350         converters={0: ast.literal_eval})
#     351 else:
# --> 352     matrix_df = distances_infer_vs_true(
#     353         matrix_df=matrix_df, sc_dis=sc_dis, rescale=rescale,
#     354         guess_hmlg_order=not hmlg_order_known, verbose=verbose)
#     355     matrix_df.to_csv(outfile_perbin, sep='\t')
#     356     redo = True  # Redo scores computed below even if file(s) exist
#
# File /net/noble/vol4/noble/user/gesine/projects/2015_gesine_diploid/bin/topsy/topsy/analysis/compare_distances.py:187, in distances_infer_vs_true(matrix_df, sc_dis, rescale, guess_hmlg_order, verbose)
#     185 print(tmp[~both_nghbrs].drop(['i.idx_ambig', 'j.idx_ambig'], axis=1))
#     186 print()
# --> 187 raise ValueError('stop here')
#     189 scale_factor = (X * Y).apply(np.mean).sum() / X.pow(2).sum()
#     190 matrix_df['dis_infer'] *= scale_factor
#
# ValueError: stop here

# %% [markdown]
# ## Infer alpha

# %%
struct_infer_files = sorted(glob.glob(struct_infer_glob))
struct_infer_files = [x for x in struct_infer_files if 'alpha_infer-intrachr' not in x and 'multires' not in x]
struct_infer_files = [x for x in struct_infer_files if 'alpha_infer-intramol' in x]
# struct_infer_files = [x for x in struct_infer_files if '.intramol' in x]
print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')

get_sc_disterror_all(
    struct_infer_files[0], sc_dis=sc_dis
    , sc_features=sc_features, rescale=True, hmlg_order_known=None,
    redo=False, verbose=True)
# Out:
# infer_ua_filter0perc.alpha_infer-intramol.singleres
# infer_ua_norm_filter0perc.alpha_infer-intramol.singleres
#
# infer_ua_filter0perc.alpha_infer-intramol.singleres/struct_inferred.000.coords
#
#
# liu2025/unambig/astro.nreads1e9.logistic_k-12.34_m1.36_v5.666e-06/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer000.rescaled
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
# count    1654.000000
# mean        2.584059
# std         4.980223
# min         0.432722
# 25%         0.939044
# 50%         1.113946
# 75%         1.461251
# max        26.904859
#
# 17.56005030888268 20.858887560106275 21.927706153738566 23.385007114166648
#               i.idx_chrom  j.idx_chrom i.chrom  i.hmlg  dis_infer
# idx
# (1, 2)                  1            2    chr1       1  24.202705
# (2, 3)                  2            3    chr1       1  23.916629
# (91, 92)               14           15    chr2       1  24.707114
# (92, 93)               15           16    chr2       1  26.283363
# (96, 97)               19           20    chr2       1  24.916791
# (97, 98)               20           21    chr2       1  25.366705
# (372, 373)             38           39    chr6       1  23.634824
# (981, 982)             18           19    chr1       2  23.712750
# (988, 989)             25           26    chr1       2  23.872526
# (989, 990)             26           27    chr1       2  25.298227
# (1005, 1006)           42           43    chr1       2  25.506577
# (1006, 1007)           43           44    chr1       2  24.366406
# (1060, 1061)           20           21    chr2       2  24.344606
# (1307, 1308)           10           11    chr6       2  24.101549
# (1310, 1311)           13           14    chr6       2  24.224981
# (1312, 1313)           15           16    chr6       2  26.735526
# (1313, 1314)           16           17    chr6       2  26.904859
# (1323, 1324)           26           27    chr6       2  25.883339
# (1335, 1336)           38           39    chr6       2  24.186105
# (1344, 1345)           47           48    chr6       2  23.392297
# (1345, 1346)           48           49    chr6       2  24.128524
# (1351, 1352)           54           55    chr6       2  24.219244
# (1502, 1503)           39           40   chr10       2  23.861369
# (1626, 1627)           15           16   chr12       2  25.799919
# (1627, 1628)           16           17   chr12       2  24.954373
# (1630, 1631)           19           20   chr12       2  24.557304
# (1631, 1632)           20           21   chr12       2  23.546477
# (1663, 1664)            5            6   chr13       2  24.992172
# (1664, 1665)            6            7   chr13       2  25.135247
# (1666, 1667)            8            9   chr13       2  23.883473
# (1684, 1685)           26           27   chr13       2  24.419978
# (1685, 1686)           27           28   chr13       2  24.920397
# (1687, 1688)           29           30   chr13       2  24.724048
# (1688, 1689)           30           31   chr13       2  24.727925
#
#               i.idx_chrom  j.idx_chrom i.chrom  i.hmlg  dis_infer  \
# idx
# (1, 2)                  1            2    chr1       1  24.202705
# (91, 92)               14           15    chr2       1  24.707114
# (96, 97)               19           20    chr2       1  24.916791
# (988, 989)             25           26    chr1       2  23.872526
# (1005, 1006)           42           43    chr1       2  25.506577
# (1312, 1313)           15           16    chr6       2  26.735526
# (1344, 1345)           47           48    chr6       2  23.392297
# (1626, 1627)           15           16   chr12       2  25.799919
# (1630, 1631)           19           20   chr12       2  24.557304
# (1663, 1664)            5            6   chr13       2  24.992172
# (1684, 1685)           26           27   chr13       2  24.419978
# (1687, 1688)           29           30   chr13       2  24.724048
#
#               i.idx_ambig  j.idx_ambig
# idx
# (1, 2)                  1            2
# (91, 92)               91           92
# (96, 97)               96           97
# (988, 989)             25           26
# (1005, 1006)           42           43
# (1312, 1313)          349          350
# (1344, 1345)          381          382
# (1626, 1627)          663          664
# (1630, 1631)          667          668
# (1663, 1664)          700          701
# (1684, 1685)          721          722
# (1687, 1688)          724          725
#
#
# Rescale inferred struct by 0.0861
# pre-rescaling: dis_infer 2.584059207470136
# dis_infer    0.222556
# dis_mean    1.041828
# dis_med     0.999327
# if rescale by dis_mean: 0.0861
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       5 print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))
#       6 print('\n' + re.sub(f'.*{counts_subdir}/', '', struct_infer_files[0]) + '\n\n')
# ----> 8 get_sc_disterror_all(
#       9     struct_infer_files[0], sc_dis=sc_dis
#      10     , sc_features=sc_features, rescale=True, hmlg_order_known=None,
#      11     redo=False, verbose=True)
#
# Cell In[4], line 517, in get_sc_disterror_all(struct_infer_files, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     515 disterror_res_mean = []
#     516 for struct_infer_file in struct_infer_files:
# --> 517     matrix_df, features_df, error, inference_type = compare_infer_vs_true(
#     518         struct_infer_file, sc_dis=sc_dis, sc_features=sc_features,
#     519         rescale=rescale, hmlg_order_known=hmlg_order_known, redo=redo,
#     520         verbose=verbose)
#     521     disterror_res = get_disterror_from_sq_dis(matrix_df, verbose=False)
#     522     disterror_res['inference'] = inference_type
#
# Cell In[4], line 340, in compare_infer_vs_true(struct_infer_file, sc_dis, sc_features, rescale, hmlg_order_known, redo, verbose)
#     336     matrix_df = pd.read_csv(
#     337         outfile_perbin, sep='\t', index_col=0,
#     338         converters={0: ast.literal_eval})
#     339 else:
# --> 340     matrix_df = distances_infer_vs_true(
#     341         matrix_df=matrix_df, sc_dis=sc_dis, rescale=rescale,
#     342         guess_hmlg_order=not hmlg_order_known, verbose=verbose)
#     343     matrix_df.to_csv(outfile_perbin, sep='\t')
#     344     redo = True  # Redo scores computed below even if file(s) exist
#
# Cell In[4], line 188, in distances_infer_vs_true(matrix_df, sc_dis, rescale, guess_hmlg_order, verbose)
#     186         Y = sc_dis.loc[mask_nghbr, 'dis_mean']
#     187         print(f'if rescale by dis_mean: {(X * Y).sum() / X.pow(2).sum():.3g}\n')
# --> 188     raise ValueError('stop here')
#     190 for col in ['disterror.vs_all', 'disterror.vs_mean', 'disterror.vs_med',
#     191             'dis_true_mean', 'dis_true_med']:
#     192     if col not in matrix_df.columns:
#
# ValueError: stop here

# %% [markdown]
# # Run

# %%
struct_infer_files = sorted(glob.glob(struct_infer_glob))

struct_infer_files = [x for x in struct_infer_files if 'alpha_infer-intrachr' not in x and 'multires' not in x]
print('\n'.join(np.unique([os.path.basename(os.path.dirname(x)) for x in struct_infer_files])))

get_sc_disterror_all(
    struct_infer_files, sc_dis=sc_dis
    , sc_features=sc_features, rescale=False, hmlg_order_known=None,
    redo=False, verbose=True)
# Out:
# infer_ua_filter0perc.alpha_infer-intramol.singleres
# infer_ua_filter0perc.singleres
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer000
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer001
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer002
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer003
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.alpha_infer-intramol.singleres/disterror_per_bin.true_vs_infer004
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer000
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer001
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer002
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer003
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# liu2025/unambig/astro.nreads1e9.logistic_k-9.12_m1.72_v1e-05/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer004
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#
# Mean results:
#                                           disterror.vs_all disterror.vs_mean  \
# inference                     err
# ua.singleres                  all                23.801874         20.734955
#                               diffC-diffH         4.895332          4.564322
#                               diffC-sameH         4.940728          4.613489
#                               diffM               4.940398          4.612776
#                               nghbr               1.380448           1.28955
#                               sameC-diffH         5.583355          5.284735
#                               sameC-sameH         1.570871          1.271384
# ua.α_infer-intramol.singleres all               563.065661        559.998742
#                               diffC-diffH        23.833669         23.767866
#                               diffC-sameH        24.251366         24.186778
#                               diffM              24.036247         23.971009
#                               nghbr               5.290271          5.267227
#                               sameC-diffH        23.732415          23.66493
#                               sameC-sameH         5.680041          5.604435
#
#                                           disterror.vs_med
# inference                     err
# ua.singleres                  all                21.687274
#                               diffC-diffH         4.668989
#                               diffC-sameH         4.718627
#                               diffM               4.717206
#                               nghbr                1.29862
#                               sameC-diffH         5.377462
#                               sameC-sameH         1.339187
# ua.α_infer-intramol.singleres all               565.601909
#                               diffC-diffH        23.887523
#                               diffC-sameH        24.306863
#                               diffM              24.090407
#                               nghbr               5.278779
#                               sameC-diffH        23.768552
#                               sameC-sameH         5.678175

# %%
# %%bash
#
# grep -E $'(alpha)\t' ~/noble_lab/projects/2015_gesine_diploid/results/liu2025/unambig/$counts_subdir/infer_ua_filter0perc.alpha_infer*/inference_params.* | sed 's/.*filter0perc.//;s/inference_params\.//'

# %% [markdown]
# # Temp

# %%
# get_sc_disterror_all(
#     struct_infer_file, sc_dis=sc_dis, hmlg_order_known=False,
#     sc_dis_are_scaled=True, redo=True, verbose=True)
# Out:
# /net/gs/vol1/home/gesine/noble_lab/projects/2015_gesine_diploid/results/liu2025/test_astro_1e6_750nm/infer_ua_filter0perc.singleres/disterror_per_bin.true_vs_infer000
# Assuming homolog ordering of inferred structure has been pre-established
# Comparing all distance bins
#             disterror.vs_all disterror.vs_mean disterror.vs_med
# all                 22.82978         20.004178        20.907642
# diffM               4.841569          4.534009         4.635017
# sameC-sameH         1.143295          0.723098         0.792076
# sameC-diffH         5.298075          5.013404         5.096436
# diffC-sameH         4.697406          4.380173         4.480505
# diffC-diffH         4.953771          4.653551         4.756468

# %%
import pandas as pd
import numpy as np
import ast

sc_dis_file = '/net/gs/vol1/home/gesine/noble_lab/repos/Chromatin_Analysis_MOp/cluster.LINK/astro/compare_to_1cell/matrix2d/astro.distances.per_locus.csv'

sc_dis = pd.read_csv(
    sc_dis_file, sep='\t', header=0, converters={
        0: ast.literal_eval, 1: str, 2: float, 3: float, 4: ast.literal_eval},
    names=('idx', 'same_molecule', 'dis_mean', 'dis_med', 'dis'))

sc_dis

sc_dis['same_molecule'] = sc_dis['same_molecule'].astype(int)

sc_dis

sc_dis.to_csv(sc_dis_file, index=False, header=False, sep='\t')

# sed 's/True/1/;s/False/0/' astro.distances.per_locus.csv > astro.distances.per_locus.csv.new
